# %% [markdown]
# # MountainCar-v0 Demo
#
# ## This activity was done using the DQN method
#
# - A car is on a one-dimensional track, positioned between two "mountains".
# - The goal is to drive up the mountain on the right;
# - however, the car's engine is not strong enough to scale the mountain in a single pass.
# - Therefore, the only way to succeed is to drive back and forth to build up momentum.

# %% [markdown]
# ## Load Packages

# %%
import random
import gym
import numpy as np
from collections import deque
from keras.models import Sequential
from keras.layers import Dense, Activation,Dropout
from keras.optimizers import Adam
from keras import backend as K
import matplotlib.pyplot as plt
from IPython.display import HTML

# %% [markdown]
# ## DQN Class

# %%
EPISODES = 400

class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=4000)
        self.gamma = 0.95    # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.997
        self.learning_rate = 0.002
        self.model = self._build_model()
        self.target_model = self._build_model()
        self.update_target_model()

    def _build_model(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        model.add(Dense(64, input_dim=2))
        model.add(Activation('relu'))

        model.add(Dense(64))
        model.add(Activation('relu'))

        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss="mean_squared_error",
                      optimizer=Adam(lr=self.learning_rate))
        return model

    def update_target_model(self):
        # copy weights from model to target_model
        self.target_model.set_weights(self.model.get_weights())

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])  # returns action

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = self.model.predict(state)
            if done:
                target[0][action] = reward
            else:
                Q_future  = self.target_model.predict(next_state)[0]
                target[0][action] = reward + self.gamma * np.amax(Q_future)
            self.model.fit(state, target, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def save(self, name):
        self.model.save(name)

# %% [markdown]
# ## Evaluation Algorithm (Main Method)

# %%
env = gym.make('MountainCar-v0')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
agent = DQNAgent(state_size, action_size)

print('state size:' ,state_size)
print('action size: ', action_size)

done = False
batch_size = 128

scores = 0
for e in range(EPISODES):
    state = env.reset()
    state = np.reshape(state, [1, state_size])
    flag = 0
    for time in range(10): #10
        action = agent.act(state)
        next_state, reward, done, info = env.step(action)

        if next_state[1] > state[0][1] and next_state[1]>0 and state[0][1]>0:
            reward += 15
        elif next_state[1] < state[0][1] and next_state[1]<=0 and state[0][1]<=0:
            reward -=15

        # give more reward if the cart reaches the flag in 200 steps
        if done:
            reward = reward + 10000
            #print('Added: ' + str(reward))
        else:
            # put a penalty if the no of time steps is more
            reward = reward - 10  
            #print('Deducted: ' + str(reward))

        next_state = np.reshape(next_state, [1, state_size])
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        scores += reward
        if done:
            flag = 1
            agent.update_target_model()
            print("episode: {}/{}, score: {}, e: {:.2}"
                  .format(e, EPISODES, scores, agent.epsilon))
                
            break

        if len(agent.memory) > batch_size:
            agent.replay(batch_size)
            
    if flag == 0:
        print("episode: {}/{}, score: {}, e: {:.2}".format(e, EPISODES, time, agent.epsilon))      
        
    if round(agent.epsilon,2) == 0.01:
        print("The top has been reached")
        break 
        
    if e % 100 == 0:
        print('saving the model')
        agent.save("mountain_car-dqn.h5")
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# state size: 2
# action size:  3
# episode: 0/400, score: 9, e: 1.0
# saving the model
# episode: 1/400, score: 9, e: 1.0
# episode: 2/400, score: 9, e: 1.0
# episode: 3/400, score: 9, e: 1.0
# episode: 4/400, score: 9, e: 1.0
# episode: 5/400, score: 9, e: 1.0
# episode: 6/400, score: 9, e: 1.0
# episode: 7/400, score: 9, e: 1.0
# episode: 8/400, score: 9, e: 1.0
# episode: 9/400, score: 9, e: 1.0
# episode: 10/400, score: 9, e: 1.0
# episode: 11/400, score: 9, e: 1.0
# episode: 12/400, score: 9, e: 0.99
# episode: 13/400, score: 9, e: 0.96
# episode: 14/400, score: 9, e: 0.94
# episode: 15/400, score: 9, e: 0.91
# episode: 16/400, score: 9, e: 0.88
# episode: 17/400, score: 9, e: 0.86
# episode: 18/400, score: 9, e: 0.83
# episode: 19/400, score: 9, e: 0.81
# episode: 20/400, score: 9, e: 0.78
# episode: 21/400, score: 9, e: 0.76
# episode: 22/400, score: 9, e: 0.74
# episode: 23/400, score: 9, e: 0.71
# episode: 24/400, score: 9, e: 0.69
# episode: 25/400, score: 9, e: 0.67
# episode: 26/400, score: 9, e: 0.65
# episode: 27/400, score: 9, e: 0.63
# episode: 28/400, score: 9, e: 0.61
# episode: 29/400, score: 9, e: 0.6
# episode: 30/400, score: 9, e: 0.58
# episode: 31/400, score: 9, e: 0.56
# episode: 32/400, score: 9, e: 0.55
# episode: 33/400, score: 9, e: 0.53
# episode: 34/400, score: 9, e: 0.51
# episode: 35/400, score: 9, e: 0.5
# episode: 36/400, score: 9, e: 0.48
# episode: 37/400, score: 9, e: 0.47
# episode: 38/400, score: 9, e: 0.46
# episode: 39/400, score: 9, e: 0.44
# episode: 40/400, score: 9, e: 0.43
# episode: 41/400, score: 9, e: 0.42
# episode: 42/400, score: 9, e: 0.4
# episode: 43/400, score: 9, e: 0.39
# episode: 44/400, score: 9, e: 0.38
# episode: 45/400, score: 9, e: 0.37
# episode: 46/400, score: 9, e: 0.36
# episode: 47/400, score: 9, e: 0.35
# episode: 48/400, score: 9, e: 0.34
# episode: 49/400, score: 9, e: 0.33
# episode: 50/400, score: 9, e: 0.32
# episode: 51/400, score: 9, e: 0.31
# episode: 52/400, score: 9, e: 0.3
# episode: 53/400, score: 9, e: 0.29
# episode: 54/400, score: 9, e: 0.28
# episode: 55/400, score: 9, e: 0.27
# episode: 56/400, score: 9, e: 0.27
# episode: 57/400, score: 9, e: 0.26
# episode: 58/400, score: 9, e: 0.25
# episode: 59/400, score: 9, e: 0.24
# episode: 60/400, score: 9, e: 0.23
# episode: 61/400, score: 9, e: 0.23
# episode: 62/400, score: 9, e: 0.22
# episode: 63/400, score: 9, e: 0.21
# episode: 64/400, score: 9, e: 0.21
# episode: 65/400, score: 9, e: 0.2
# episode: 66/400, score: 9, e: 0.2
# episode: 67/400, score: 9, e: 0.19
# episode: 68/400, score: 9, e: 0.18
# episode: 69/400, score: 9, e: 0.18
# episode: 70/400, score: 9, e: 0.17
# episode: 71/400, score: 9, e: 0.17
# episode: 72/400, score: 9, e: 0.16
# episode: 73/400, score: 9, e: 0.16
# episode: 74/400, score: 9, e: 0.15
# episode: 75/400, score: 9, e: 0.15
# episode: 76/400, score: 9, e: 0.15
# episode: 77/400, score: 9, e: 0.14
# episode: 78/400, score: 9, e: 0.14
# episode: 79/400, score: 9, e: 0.13
# episode: 80/400, score: 9, e: 0.13
# episode: 81/400, score: 9, e: 0.13
# episode: 82/400, score: 9, e: 0.12
# episode: 83/400, score: 9, e: 0.12
# episode: 84/400, score: 9, e: 0.11
# episode: 85/400, score: 9, e: 0.11
# episode: 86/400, score: 9, e: 0.11
# episode: 87/400, score: 9, e: 0.1
# episode: 88/400, score: 9, e: 0.1
# episode: 89/400, score: 9, e: 0.098
# episode: 90/400, score: 9, e: 0.095
# episode: 91/400, score: 9, e: 0.093
# episode: 92/400, score: 9, e: 0.09
# episode: 93/400, score: 9, e: 0.087
# episode: 94/400, score: 9, e: 0.085
# episode: 95/400, score: 9, e: 0.082
# episode: 96/400, score: 9, e: 0.08
# episode: 97/400, score: 9, e: 0.077
# episode: 98/400, score: 9, e: 0.075
# episode: 99/400, score: 9, e: 0.073
# episode: 100/400, score: 9, e: 0.071
# saving the model
# episode: 101/400, score: 9, e: 0.069
# episode: 102/400, score: 9, e: 0.067
# episode: 103/400, score: 9, e: 0.065
# episode: 104/400, score: 9, e: 0.063
# episode: 105/400, score: 9, e: 0.061
# episode: 106/400, score: 9, e: 0.059
# episode: 107/400, score: 9, e: 0.057
# episode: 108/400, score: 9, e: 0.056
# episode: 109/400, score: 9, e: 0.054
# episode: 110/400, score: 9, e: 0.052
# episode: 111/400, score: 9, e: 0.051
# episode: 112/400, score: 9, e: 0.049
# episode: 113/400, score: 9, e: 0.048
# episode: 114/400, score: 9, e: 0.046
# episode: 115/400, score: 9, e: 0.045
# episode: 116/400, score: 9, e: 0.044
# episode: 117/400, score: 9, e: 0.042
# episode: 118/400, score: 9, e: 0.041
# episode: 119/400, score: 9, e: 0.04
# episode: 120/400, score: 9, e: 0.039
# episode: 121/400, score: 9, e: 0.038
# episode: 122/400, score: 9, e: 0.036
# episode: 123/400, score: 9, e: 0.035
# episode: 124/400, score: 9, e: 0.034
# episode: 125/400, score: 9, e: 0.033
# episode: 126/400, score: 9, e: 0.032
# episode: 127/400, score: 9, e: 0.031
# episode: 128/400, score: 9, e: 0.03
# episode: 129/400, score: 9, e: 0.03
# episode: 130/400, score: 9, e: 0.029
# episode: 131/400, score: 9, e: 0.028
# episode: 132/400, score: 9, e: 0.027
# episode: 133/400, score: 9, e: 0.026
# episode: 134/400, score: 9, e: 0.025
# episode: 135/400, score: 9, e: 0.025
# episode: 136/400, score: 9, e: 0.024
# episode: 137/400, score: 9, e: 0.023
# episode: 138/400, score: 9, e: 0.023
# episode: 139/400, score: 9, e: 0.022
# episode: 140/400, score: 9, e: 0.021
# episode: 141/400, score: 9, e: 0.021
# episode: 142/400, score: 9, e: 0.02
# episode: 143/400, score: 9, e: 0.019
# episode: 144/400, score: 9, e: 0.019
# episode: 145/400, score: 9, e: 0.018
# episode: 146/400, score: 9, e: 0.018
# episode: 147/400, score: 9, e: 0.017
# episode: 148/400, score: 9, e: 0.017
# episode: 149/400, score: 9, e: 0.016
# episode: 150/400, score: 9, e: 0.016
# episode: 151/400, score: 9, e: 0.015
# episode: 152/400, score: 9, e: 0.015
# The top has been reached

# %% [markdown]
# ## Visualisation

# %%
HTML('<img src="Mountain Car.gif">')
# Out:
# <img src="Mountain Car.gif">
